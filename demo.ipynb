# %% [markdown]
# ## Simple demo using pre-preprocessed data

# %%
import Load_forecasting
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Using TensorFlow backend.

# %%
forecaster = Load_forecasting.Load_Forecaster()

# %%
forecaster.load_data('data_UK_weather')

# %%
forecaster._override_training_settings(epochs=5, lossplot=True)
forecaster.train_model('GRU', RNN=True)
# Out:
# Reloading best model
# TOTAL TRAINING TIME : 17.109785318374634

# %%
forecaster.predict_load(graph=True, store=False)
# Out:
# [TRAINING SET] - global error : 0    3.649594
# dtype: float64% MAPE
# [TESTING  SET] - global error : 0    4.205611
# dtype: float64% MAPE
# [TRAINING SET] - global error : 0    3.690546
# dtype: float64% MAPE
# [TESTING  SET] - global error : 0    4.892818
# dtype: float64% MAPE
# [TRAINING SET] - global error : 0    3.720392
# dtype: float64% MAPE
# [TESTING  SET] - global error : 0    4.953321
# dtype: float64% MAPE
